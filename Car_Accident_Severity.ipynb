# %% [markdown]
# # Capstone Project - Car Accident Severity
# ### Applied Data Science Capstone by IBM/Coursera
#
#
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Prediction](#prediction)
# * [Results and Evaluation](#results)
# * [Discussion](#discussion)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>
#
# In this Capstone project, I will attempt to find the leading factors to traffic accidents in the Seattle, Washinton Area. Specifically, this report will targeting the local Seatlle Government to provide more specific information about the **severity traffic accidents** in the city. More specifically, I will leverage the accident data that I found to **predict the different accidents' severity,** by building a **machine learning (ML) model to predict accident severity**, based on fatilities, traffic delays, and other related data.

# %% [markdown]
# ## Data <a name="data"></a>
# After obtaining a greater understanding of the issues with traffic accidents in the Seattle, Washington area, I decided to use the sample **"Data-Collisions.csv"** file, provided by *IBM Watson* to assist in the the prediction of traffic accidents' severity. The data included contain accident records in Seattle of a date range from 01January2004 to 02May2020. In the data set, there are 194673 events.
#
# Based on definition of our problem, factors that will influence decisions makers are the following:
# * Number of pedestrians in the various mediums (e.g., in vehicles, bicycles, walking, etc.)
# * Number of vehicles involved
# * Other environmental factors of contribution (e.g., weather, road conditions, lighting)
# * Along with the severity level of the accident
#
# As a result, the following attributes will be analyzed:
# * The target for prediction being **SEVERITYCODE**, as that is what is used to measure the severity of the accident. This column has two possible values, as follows:
# ** 1 - Property Damage
# ** 2 - Injury
# * The features that will be used to predict the severity level are the following:
# ** PEDCOUNT
# ** PEDCYLCOUNT
# ** VEHCOUNT
# ** WEATHER
# ** ROADCOND
# ** LIGHTCOND
# ** and the newly created 'Seattle Seasons'
#
# * Note: Some of these items are categorial and will need to be changed so that the ML models can handle these items.

# %%
# Import packages needed for the notebook
import pandas as pd
import numpy as np
import csv
import os
import datetime as dt
# %matplotlib inline 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

print('Import Complete')

#Create directory for graph save:
mydir = 'Car_Accident_Charts'
if not os.path.isdir(mydir):
    os.mkdir(mydir)
print('Directory Creation Complete')
# Out:
# Import Complete
# Directory Creation Complete

# %%
#Upload sample data for analysis. This includes the setting of display.max_columns to see all of the columns in the data set. 
pd.set_option('display.max_columns', None)
df1 = pd.read_csv('https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv')
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Make a copy of the data frame for editing
df = df1.copy()

# %%
#Obtain basic statistics about the data set
data_info  = 'The following are the descriptive stats of the dataframe: \n'
data_info += '\t Data Shape: ' + str(df.shape) + '\n'
data_info += '\n'
data_info += '\t Data columns: ' + str(df.columns) + '\n'
data_info += '\n'
data_info += '\t Descriptive Statistics: ' + str(df.describe) + '\n'
data_info += '\n'
data_info += '\t Data Types: ' + str(df.dtypes) + '\n'
print(data_info)
# Out:
# The following are the descriptive stats of the dataframe:
# 	 Data Shape: (194673, 38)
#
# 	 Data columns: Index(['SEVERITYCODE', 'X', 'Y', 'OBJECTID', 'INCKEY', 'COLDETKEY', 'REPORTNO',
#        'STATUS', 'ADDRTYPE', 'INTKEY', 'LOCATION', 'EXCEPTRSNCODE',
#        'EXCEPTRSNDESC', 'SEVERITYCODE.1', 'SEVERITYDESC', 'COLLISIONTYPE',
#        'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INCDATE',
#        'INCDTTM', 'JUNCTIONTYPE', 'SDOT_COLCODE', 'SDOT_COLDESC',
#        'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND',
#        'PEDROWNOTGRNT', 'SDOTCOLNUM', 'SPEEDING', 'ST_COLCODE', 'ST_COLDESC',
#        'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR'],
#       dtype='object')
#
# 	 Descriptive Statistics: <bound method NDFrame.describe of         SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY  \
# 0                  2 -122.323148  47.703140         1    1307       1307
# 1                  1 -122.347294  47.647172         2   52200      52200
# 2                  1 -122.334540  47.607871         3   26700      26700
# 3                  1 -122.334803  47.604803         4    1144       1144
# 4                  2 -122.306426  47.545739         5   17700      17700
# 5                  1 -122.387598  47.690575         6  320840     322340
# 6                  1 -122.338485  47.618534         7   83300      83300
# 7                  2 -122.320780  47.614076         9  330897     332397
# 8                  1 -122.335930  47.611904        10   63400      63400
# 9                  2 -122.384700  47.528475        12   58600      58600
# 10                 1         NaN        NaN        14   48900      48900
# 11                 1 -122.333831  47.547371        15   38800      38800
# 12                 1 -122.356273  47.571375        16    2771       2771
# 13                 1 -122.323966  47.606374        17   32800      32800
# 14                 2 -122.317414  47.664028        19    1212       1212
# 15                 1 -122.337663  47.617510        20  330878     332378
# 16                 2 -122.344539  47.692012        21   46300      46300
# 17                 1         NaN        NaN        23   23000      23000
# 18                 2 -122.328270  47.571420        24  330833     332333
# 19                 1 -122.383802  47.583715        25   97100      97100
# 20                 2 -122.292403  47.732847        26    1347       1347
# 21                 2 -122.313786  47.708535        28    1323       1323
# 22                 1 -122.318169  47.615837        29   80000      80000
# 23                 1 -122.337486  47.589746        31   28700      28700
# 24                 2 -122.279658  47.553405        33    1268       1268
# 25                 2 -122.312857  47.599218        34  320932     322432
# 26                 1 -122.330730  47.615450        35  113300     113300
# 27                 1 -122.385859  47.581191        36   64700      64700
# 28                 1 -122.304990  47.611474        37    1083       1083
# 29                 1         NaN        NaN        38   61500      61500
# ...              ...         ...        ...       ...     ...        ...
# 194643             1 -122.345863  47.612991    219510  307577     308857
# 194644             1 -122.330298  47.603233    219511  312117     313537
# 194645             2 -122.328079  47.604161    219512  307692     308972
# 194646             1 -122.320756  47.608656    219513  312289     313709
# 194647             2 -122.355449  47.704720    219514  308575     309855
# 194648             1 -122.357624  47.635956    219515  307792     309072
# 194649             2 -122.302382  47.626759    219516  307985     309265
# 194650             2 -122.355298  47.684382    219517  310417     311717
# 194651             1 -122.320780  47.614076    219519  309594     310874
# 194652             1 -122.335527  47.617434    219520  308698     309978
# 194653             2 -122.322097  47.649615    219521  308342     309622
# 194654             1 -122.312679  47.719414    219522  311117     312437
# 194655             2 -122.380016  47.664879    219523  310911     312231
# 194656             2 -122.340474  47.614496    219524  312179     313599
# 194657             1 -122.337137  47.610709    219525  307834     309114
# 194658             1 -122.302554  47.584099    219528  311697     313057
# 194659             1 -122.298955  47.717456    219529  308019     309299
# 194660             2         NaN        NaN    219531  308990     310270
# 194661             2 -122.306092  47.617881    219532  308532     309812
# 194662             1 -122.337880  47.625793    219535  307802     309082
# 194663             2 -122.299160  47.579673    219536  309335     310615
# 194664             1 -122.325887  47.643191    219537  309222     310502
# 194665             1 -122.304217  47.669537    219538  308480     309760
# 194666             2 -122.344569  47.694547    219539  309170     310450
# 194667             1 -122.361672  47.556722    219541  307804     309084
# 194668             2 -122.290826  47.565408    219543  309534     310814
# 194669             1 -122.344526  47.690924    219544  309085     310365
# 194670             2 -122.306689  47.683047    219545  311280     312640
# 194671             2 -122.355317  47.678734    219546  309514     310794
# 194672             1 -122.289360  47.611017    219547  308220     309500
#
#        REPORTNO     STATUS      ADDRTYPE   INTKEY  \
# 0       3502005    Matched  Intersection  37475.0
# 1       2607959    Matched         Block      NaN
# 2       1482393    Matched         Block      NaN
# 3       3503937    Matched         Block      NaN
# 4       1807429    Matched  Intersection  34387.0
# 5       E919477    Matched  Intersection  36974.0
# 6       3282542    Matched  Intersection  29510.0
# 7       EA30304    Matched  Intersection  29745.0
# 8       2071243    Matched         Block      NaN
# 9       2072105    Matched  Intersection  34679.0
# 10      2024040    Matched         Alley      NaN
# 11      C654800    Matched  Intersection  33194.0
# 12      1211870  Unmatched         Block      NaN
# 13      2128498    Matched         Block      NaN
# 14      3507861    Matched         Block      NaN
# 15      3838086  Unmatched         Block      NaN
# 16      2023080    Matched  Intersection  37365.0
# 17       537838    Matched         Block      NaN
# 18      EA29752    Matched         Block      NaN
# 19      2894590    Matched         Block      NaN
# 20      3608880    Matched         Block      NaN
# 21      3502831    Matched  Intersection  36505.0
# 22      2882620    Matched         Block      NaN
# 23      1213894    Matched         Block      NaN
# 24      3672152    Matched  Intersection  33499.0
# 25      E926429    Matched         Block      NaN
# 26      3346338    Matched  Intersection  29865.0
# 27      2798260    Matched         Block      NaN
# 28      3605909    Matched         Block      NaN
# 29      2607270    Matched         Block      NaN
# ...         ...        ...           ...      ...
# 194643  3811871    Matched         Block      NaN
# 194644  E885893    Matched  Intersection  30479.0
# 194645  E851047    Matched  Intersection  29973.0
# 194646  E872044  Unmatched         Block      NaN
# 194647  E872078    Matched         Block      NaN
# 194648  3578593    Matched         Block      NaN
# 194649  E869075    Matched  Intersection  29328.0
# 194650  3751221    Matched         Block      NaN
# 194651  E881227    Matched  Intersection  29745.0
# 194652  3812450    Matched         Block      NaN
# 194653  3693206    Matched         Block      NaN
# 194654  E881587  Unmatched  Intersection  36427.0
# 194655  3751425  Unmatched  Intersection  25174.0
# 194656  E885580    Matched  Intersection  29545.0
# 194657  3811279    Matched         Block      NaN
# 194658  E886941    Matched         Block      NaN
# 194659  3767486    Matched         Block      NaN
# 194660  3811749    Matched         Block      NaN
# 194661  3814599    Matched         Block      NaN
# 194662  E869008    Matched         Block      NaN
# 194663  E880807    Matched         Block      NaN
# 194664  E879537    Matched  Intersection  28300.0
# 194665  3642620    Matched  Intersection  26005.0
# 194666  E879712    Matched         Block      NaN
# 194667  3745813    Matched         Block      NaN
# 194668  E871089    Matched         Block      NaN
# 194669  E876731    Matched         Block      NaN
# 194670  3809984    Matched  Intersection  24760.0
# 194671  3810083    Matched  Intersection  24349.0
# 194672  E868008    Matched         Block      NaN
#
#                                                  LOCATION EXCEPTRSNCODE  \
# 0                              5TH AVE NE AND NE 103RD ST
# 1              AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N           NaN
# 2             4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST           NaN
# 3                2ND AVE BETWEEN MARION ST AND MADISON ST
# 4                         SWIFT AVE S AND SWIFT AV OFF RP           NaN
# 5                              24TH AVE NW AND NW 85TH ST
# 6                              DENNY WAY AND WESTLAKE AVE           NaN
# 7                                  BROADWAY AND E PIKE ST
# 8                     PINE ST BETWEEN 5TH AVE AND 6TH AVE           NaN
# 9                           41ST AVE SW AND SW THISTLE ST           NaN
# 10                                                    NaN           NaN
# 11                 1ST AV S BR NB AND EAST MARGINAL WAY S           NaN
# 12      SW SPOKANE ST BETWEEN SW SPOKANE W BR AND TERM...
# 13               TERRY AVE BETWEEN JAMES ST AND CHERRY ST           NaN
# 14      ROOSEVELT WAY NE BETWEEN NE 47TH ST AND NE 50T...
# 15             9TH AVE BETWEEN LENORA ST AND BLANCHARD ST
# 16                             AURORA AVE N AND N 87TH ST           NaN
# 17      BATTERY ST TUN ON RP BETWEEN BELL ST AND ALASK...           NaN
# 18        S SPOKANE SR ST BETWEEN 4TH AVE S AND 5TH AVE S
# 19      41ST AVE SW BETWEEN SW WALKER ST AND SW COLLEG...           NaN
# 20      LAKE CITY WAY NE BETWEEN NE 143RD ST AND NE 14...
# 21                       14TH AVE NE AND NE NORTHGATE WAY
# 22              11TH AVE BETWEEN E PINE ST AND E OLIVE ST           NaN
# 23      ALASKAN WY VI SB BETWEEN ALASKAN WY VI SB EFR ...           NaN
# 24                         RAINIER AVE S AND S BRANDON ST
# 25         S JACKSON ST BETWEEN 14TH AVE S AND 16TH AVE S
# 26                                BOREN AVE AND OLIVE WAY           NaN
# 27      SW ADMIRAL WAY BETWEEN 42ND AVE SW AND CALIFOR...           NaN
# 28            21ST AVE BETWEEN E MARION ST AND E UNION ST
# 29      1ST AVE S BETWEEN 1ST AVS ON N RP AND S ROYAL ...           NaN
# ...                                                   ...           ...
# 194643           1ST AVE BETWEEN BLANCHARD ST AND BELL ST
# 194644                               4TH AVE AND JAMES ST
# 194645                               6TH AVE AND JAMES ST
# 194646       BROADWAY BETWEEN CHERRY ST AND E COLUMBIA ST
# 194647  GREENWOOD AVE N BETWEEN N 104TH ST AND HOLMAN ...
# 194648   W HOWE ST BETWEEN QUEEN ANNE AVE N AND 1ST AVE W
# 194649                          23RD AVE E AND E ALOHA ST
# 194650    GREENWOOD AVE N BETWEEN N 76TH ST AND N 77TH ST
# 194651                             BROADWAY AND E PIKE ST
# 194652        TERRY AVE BETWEEN VIRGINIA ST AND LENORA ST
# 194653  HARVARD AVE E BETWEEN E ALLISON ST AND EASTLAK...
# 194654                        15TH AVE NE AND NE 125TH ST
# 194655                        LEARY AVE NW AND NW DOCK PL
# 194656                              5TH AVE AND LENORA ST
# 194657                4TH AVE BETWEEN PIKE ST AND PINE ST           NEI
# 194658   RAINIER AVE S BETWEEN 23RD AVE S AND S WALKER ST
# 194659    NE 123RD ST BETWEEN HIRAM PL NE AND 28TH AVE NE           NEI
# 194660  BATTERY ST TUNNEL NB BETWEEN ALASKAN WY VI NB ...
# 194661      20TH AVE BETWEEN E MADISON ST AND E DENNY WAY
# 194662   VALLEY ST BETWEEN WESTLAKE AVE N AND TERRY AVE N
# 194663  RAINIER AVE S BETWEEN S BAYVIEW ST AND S MCCLE...
# 194664                    EASTLAKE AVE E AND E ROANOKE ST
# 194665                    NE PARK RD AND NE RAVENNA WB BV
# 194666       AURORA AVE N BETWEEN N 90TH ST AND N 91ST ST
# 194667  PUGET BLVD SW BETWEEN SW HUDSON ST AND DEAD END 1
# 194668    34TH AVE S BETWEEN S DAKOTA ST AND S GENESEE ST
# 194669       AURORA AVE N BETWEEN N 85TH ST AND N 86TH ST
# 194670                         20TH AVE NE AND NE 75TH ST
# 194671                      GREENWOOD AVE N AND N 68TH ST
# 194672       34TH AVE BETWEEN E MARION ST AND E SPRING ST
#
#                                             EXCEPTRSNDESC  SEVERITYCODE.1  \
# 0                                                     NaN               2
# 1                                                     NaN               1
# 2                                                     NaN               1
# 3                                                     NaN               1
# 4                                                     NaN               2
# 5                                                     NaN               1
# 6                                                     NaN               1
# 7                                                     NaN               2
# 8                                                     NaN               1
# 9                                                     NaN               2
# 10                                                    NaN               1
# 11                                                    NaN               1
# 12                                                    NaN               1
# 13                                                    NaN               1
# 14                                                    NaN               2
# 15                                                    NaN               1
# 16                                                    NaN               2
# 17                                                    NaN               1
# 18                                                    NaN               2
# 19                                                    NaN               1
# 20                                                    NaN               2
# 21                                                    NaN               2
# 22                                                    NaN               1
# 23                                                    NaN               1
# 24                                                    NaN               2
# 25                                                    NaN               2
# 26                                                    NaN               1
# 27                                                    NaN               1
# 28                                                    NaN               1
# 29                                                    NaN               1
# ...                                                   ...             ...
# 194643                                                NaN               1
# 194644                                                NaN               1
# 194645                                                NaN               2
# 194646                                                NaN               1
# 194647                                                NaN               2
# 194648                                                NaN               1
# 194649                                                NaN               2
# 194650                                                NaN               2
# 194651                                                NaN               1
# 194652                                                NaN               1
# 194653                                                NaN               2
# 194654                                                NaN               1
# 194655                                                NaN               2
# 194656                                                NaN               2
# 194657  Not Enough Information, or Insufficient Locati...               1
# 194658                                                NaN               1
# 194659  Not Enough Information, or Insufficient Locati...               1
# 194660                                                NaN               2
# 194661                                                NaN               2
# 194662                                                NaN               1
# 194663                                                NaN               2
# 194664                                                NaN               1
# 194665                                                NaN               1
# 194666                                                NaN               2
# 194667                                                NaN               1
# 194668                                                NaN               2
# 194669                                                NaN               1
# 194670                                                NaN               2
# 194671                                                NaN               2
# 194672                                                NaN               1
#
#                           SEVERITYDESC COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  \
# 0                     Injury Collision        Angles            2         0
# 1       Property Damage Only Collision     Sideswipe            2         0
# 2       Property Damage Only Collision    Parked Car            4         0
# 3       Property Damage Only Collision         Other            3         0
# 4                     Injury Collision        Angles            2         0
# 5       Property Damage Only Collision        Angles            2         0
# 6       Property Damage Only Collision        Angles            2         0
# 7                     Injury Collision        Cycles            3         0
# 8       Property Damage Only Collision    Parked Car            2         0
# 9                     Injury Collision        Angles            2         0
# 10      Property Damage Only Collision         Other            2         0
# 11      Property Damage Only Collision        Angles            2         0
# 12      Property Damage Only Collision    Rear Ended            0         0
# 13      Property Damage Only Collision    Parked Car            2         0
# 14                    Injury Collision       Head On            2         0
# 15      Property Damage Only Collision           NaN            1         0
# 16                    Injury Collision     Left Turn            3         0
# 17      Property Damage Only Collision    Rear Ended            0         0
# 18                    Injury Collision    Rear Ended            4         0
# 19      Property Damage Only Collision    Parked Car            2         0
# 20                    Injury Collision    Rear Ended            3         0
# 21                    Injury Collision        Angles            5         0
# 22      Property Damage Only Collision    Parked Car            2         0
# 23      Property Damage Only Collision         Other            1         0
# 24                    Injury Collision    Rear Ended            3         0
# 25                    Injury Collision        Cycles            2         0
# 26      Property Damage Only Collision     Left Turn            2         0
# 27      Property Damage Only Collision        Angles            2         0
# 28      Property Damage Only Collision         Other            2         0
# 29      Property Damage Only Collision    Parked Car            2         0
# ...                                ...           ...          ...       ...
# 194643  Property Damage Only Collision    Parked Car            2         0
# 194644  Property Damage Only Collision        Angles            2         0
# 194645                Injury Collision    Right Turn            5         0
# 194646  Property Damage Only Collision           NaN            2         0
# 194647                Injury Collision    Pedestrian            2         1
# 194648  Property Damage Only Collision        Angles            2         0
# 194649                Injury Collision     Left Turn            6         0
# 194650                Injury Collision    Parked Car            5         0
# 194651  Property Damage Only Collision    Pedestrian            3         1
# 194652  Property Damage Only Collision    Parked Car            3         0
# 194653                Injury Collision    Parked Car            6         0
# 194654  Property Damage Only Collision           NaN            2         0
# 194655                Injury Collision           NaN            4         0
# 194656                Injury Collision    Pedestrian            2         1
# 194657  Property Damage Only Collision     Sideswipe            2         0
# 194658  Property Damage Only Collision    Rear Ended            3         0
# 194659  Property Damage Only Collision    Parked Car            2         0
# 194660                Injury Collision         Other            1         0
# 194661                Injury Collision     Left Turn            2         0
# 194662  Property Damage Only Collision    Parked Car            2         0
# 194663                Injury Collision        Angles            3         0
# 194664  Property Damage Only Collision        Angles            8         0
# 194665  Property Damage Only Collision        Angles            2         0
# 194666                Injury Collision        Angles            2         0
# 194667  Property Damage Only Collision         Other            1         0
# 194668                Injury Collision       Head On            3         0
# 194669  Property Damage Only Collision    Rear Ended            2         0
# 194670                Injury Collision     Left Turn            3         0
# 194671                Injury Collision        Cycles            2         0
# 194672  Property Damage Only Collision    Rear Ended            2         0
#
#         PEDCYLCOUNT  VEHCOUNT                 INCDATE                 INCDTTM  \
# 0                 0         2  2013/03/27 00:00:00+00    3/27/2013 2:54:00 PM
# 1                 0         2  2006/12/20 00:00:00+00   12/20/2006 6:55:00 PM
# 2                 0         3  2004/11/18 00:00:00+00  11/18/2004 10:20:00 AM
# 3                 0         3  2013/03/29 00:00:00+00    3/29/2013 9:26:00 AM
# 4                 0         2  2004/01/28 00:00:00+00    1/28/2004 8:04:00 AM
# 5                 0         2  2019/04/20 00:00:00+00    4/20/2019 5:42:00 PM
# 6                 0         2  2008/12/09 00:00:00+00               12/9/2008
# 7                 1         1  2020/04/15 00:00:00+00    4/15/2020 5:47:00 PM
# 8                 0         2  2006/06/15 00:00:00+00    6/15/2006 1:00:00 PM
# 9                 0         2  2006/03/20 00:00:00+00    3/20/2006 3:49:00 PM
# 10                0         2  2006/05/25 00:00:00+00    5/25/2006 6:20:00 PM
# 11                0         2  2005/08/11 00:00:00+00    8/11/2005 5:30:00 PM
# 12                0         2  2006/05/17 00:00:00+00   5/17/2006 12:51:00 PM
# 13                0         2  2005/12/22 00:00:00+00   12/22/2005 5:13:00 PM
# 14                0         2  2013/03/31 00:00:00+00    3/31/2013 2:09:00 AM
# 15                0         0  2020/04/20 00:00:00+00               4/20/2020
# 16                0         2  2005/07/01 00:00:00+00                7/1/2005
# 17                0         2  2004/01/16 00:00:00+00    1/16/2004 8:25:00 AM
# 18                0         3  2020/04/17 00:00:00+00    4/17/2020 2:44:00 PM
# 19                0         2  2009/06/01 00:00:00+00                6/1/2009
# 20                0         2  2013/03/27 00:00:00+00    3/27/2013 8:45:00 PM
# 21                0         3  2013/03/28 00:00:00+00    3/28/2013 4:22:00 PM
# 22                0         2  2008/07/18 00:00:00+00   7/18/2008 10:02:00 PM
# 23                0         1  2004/09/12 00:00:00+00    9/12/2004 6:20:00 AM
# 24                0         2  2013/03/31 00:00:00+00   3/31/2013 10:05:00 AM
# 25                1         1  2019/04/25 00:00:00+00    4/25/2019 9:40:00 AM
# 26                0         2  2010/11/13 00:00:00+00   11/13/2010 3:24:00 PM
# 27                0         2  2007/07/23 00:00:00+00    7/23/2007 4:30:00 PM
# 28                0         2  2013/03/25 00:00:00+00    3/25/2013 2:42:00 PM
# 29                0         2  2006/11/16 00:00:00+00  11/16/2006 11:00:00 AM
# ...             ...       ...                     ...                     ...
# 194643            0         2  2018/11/17 00:00:00+00  11/17/2018 11:06:00 PM
# 194644            0         2  2019/01/17 00:00:00+00    1/17/2019 5:11:00 PM
# 194645            0         2  2018/10/20 00:00:00+00   10/20/2018 2:07:00 AM
# 194646            0         0  2018/12/13 00:00:00+00              12/13/2018
# 194647            0         1  2018/12/09 00:00:00+00    12/9/2018 6:15:00 PM
# 194648            0         2  2018/11/30 00:00:00+00   11/30/2018 6:42:00 PM
# 194649            0         3  2018/12/02 00:00:00+00    12/2/2018 6:54:00 PM
# 194650            0         5  2019/01/13 00:00:00+00    1/13/2019 8:36:00 AM
# 194651            0         1  2018/12/23 00:00:00+00   12/23/2018 9:45:00 PM
# 194652            0         2  2018/12/20 00:00:00+00   12/20/2018 4:21:00 PM
# 194653            0         6  2018/12/10 00:00:00+00  12/10/2018 12:47:00 AM
# 194654            0         0  2019/01/10 00:00:00+00               1/10/2019
# 194655            0         0  2019/01/20 00:00:00+00               1/20/2019
# 194656            0         1  2019/01/23 00:00:00+00   1/23/2019 10:15:00 AM
# 194657            0         2  2018/11/26 00:00:00+00   11/26/2018 3:37:00 AM
# 194658            0         3  2019/01/18 00:00:00+00    1/18/2019 9:57:00 PM
# 194659            0         2  2018/11/27 00:00:00+00   11/27/2018 5:30:00 PM
# 194660            0         1  2018/12/23 00:00:00+00  12/23/2018 12:52:00 PM
# 194661            0         2  2019/03/22 00:00:00+00    3/22/2019 5:19:00 PM
# 194662            0         2  2018/12/05 00:00:00+00    12/5/2018 5:09:00 PM
# 194663            0         2  2019/01/09 00:00:00+00    1/9/2019 12:51:00 PM
# 194664            0         3  2018/12/30 00:00:00+00   12/30/2018 3:25:00 PM
# 194665            0         2  2018/12/05 00:00:00+00    12/5/2018 1:00:00 PM
# 194666            0         2  2019/01/04 00:00:00+00     1/4/2019 1:46:00 PM
# 194667            0         1  2018/11/28 00:00:00+00   11/28/2018 9:34:00 PM
# 194668            0         2  2018/11/12 00:00:00+00   11/12/2018 8:12:00 AM
# 194669            0         2  2018/12/18 00:00:00+00   12/18/2018 9:14:00 AM
# 194670            0         2  2019/01/19 00:00:00+00    1/19/2019 9:25:00 AM
# 194671            1         1  2019/01/15 00:00:00+00    1/15/2019 4:48:00 PM
# 194672            0         2  2018/11/30 00:00:00+00   11/30/2018 3:45:00 PM
#
#                                              JUNCTIONTYPE  SDOT_COLCODE  \
# 0                  At Intersection (intersection related)            11
# 1                 Mid-Block (not related to intersection)            16
# 2                 Mid-Block (not related to intersection)            14
# 3                 Mid-Block (not related to intersection)            11
# 4                  At Intersection (intersection related)            11
# 5                  At Intersection (intersection related)            11
# 6                  At Intersection (intersection related)            11
# 7                  At Intersection (intersection related)            51
# 8                 Mid-Block (not related to intersection)            11
# 9                  At Intersection (intersection related)            11
# 10                                      Driveway Junction            11
# 11                 At Intersection (intersection related)            11
# 12                Mid-Block (not related to intersection)            14
# 13                Mid-Block (not related to intersection)            13
# 14                Mid-Block (not related to intersection)            11
# 15                                      Driveway Junction            26
# 16                 At Intersection (intersection related)            11
# 17                   Mid-Block (but intersection related)            14
# 18                Mid-Block (not related to intersection)            14
# 19                Mid-Block (not related to intersection)            11
# 20                Mid-Block (not related to intersection)            14
# 21                 At Intersection (intersection related)            11
# 22                Mid-Block (not related to intersection)            11
# 23                Mid-Block (not related to intersection)            28
# 24                 At Intersection (intersection related)            14
# 25                Mid-Block (not related to intersection)            18
# 26                 At Intersection (intersection related)            11
# 27                                      Driveway Junction            11
# 28                Mid-Block (not related to intersection)            14
# 29                Mid-Block (not related to intersection)            16
# ...                                                   ...           ...
# 194643            Mid-Block (not related to intersection)            11
# 194644             At Intersection (intersection related)            11
# 194645  At Intersection (but not related to intersection)            11
# 194646            Mid-Block (not related to intersection)            14
# 194647            Mid-Block (not related to intersection)            14
# 194648            Mid-Block (not related to intersection)            11
# 194649             At Intersection (intersection related)            11
# 194650            Mid-Block (not related to intersection)            14
# 194651             At Intersection (intersection related)            24
# 194652            Mid-Block (not related to intersection)            11
# 194653            Mid-Block (not related to intersection)            11
# 194654             At Intersection (intersection related)            11
# 194655             At Intersection (intersection related)            24
# 194656             At Intersection (intersection related)            24
# 194657            Mid-Block (not related to intersection)             0
# 194658            Mid-Block (not related to intersection)            14
# 194659                                                NaN             0
# 194660            Mid-Block (not related to intersection)            29
# 194661               Mid-Block (but intersection related)            14
# 194662               Mid-Block (but intersection related)            14
# 194663            Mid-Block (not related to intersection)            11
# 194664             At Intersection (intersection related)            11
# 194665             At Intersection (intersection related)            11
# 194666            Mid-Block (not related to intersection)            11
# 194667            Mid-Block (not related to intersection)            28
# 194668            Mid-Block (not related to intersection)            11
# 194669            Mid-Block (not related to intersection)            14
# 194670             At Intersection (intersection related)            11
# 194671             At Intersection (intersection related)            51
# 194672            Mid-Block (not related to intersection)            14
#
#                                              SDOT_COLDESC INATTENTIONIND  \
# 0       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 1       MOTOR VEHICLE STRUCK MOTOR VEHICLE, LEFT SIDE ...            NaN
# 2            MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 3       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 4       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 5       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 6       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 7       PEDALCYCLIST STRUCK MOTOR VEHICLE FRONT END AT...            NaN
# 8       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 9       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 10      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 11      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 12           MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 13      MOTOR VEHICLE STRUCK MOTOR VEHICLE, LEFT SIDE ...            NaN
# 14      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 15                    MOTOR VEHICLE STRUCK OBJECT IN ROAD            NaN
# 16      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 17           MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 18           MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 19      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 20           MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 21      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 22      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...              Y
# 23          MOTOR VEHICLE RAN OFF ROAD - HIT FIXED OBJECT            NaN
# 24           MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 25      MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...              Y
# 26      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 27      MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 28           MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 29      MOTOR VEHICLE STRUCK MOTOR VEHICLE, LEFT SIDE ...            NaN
# ...                                                   ...            ...
# 194643  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194644  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194645  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194646       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 194647       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END              Y
# 194648  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194649  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194650       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 194651                    MOTOR VEHCILE STRUCK PEDESTRIAN            NaN
# 194652  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...              Y
# 194653  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194654  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194655                    MOTOR VEHCILE STRUCK PEDESTRIAN            NaN
# 194656                    MOTOR VEHCILE STRUCK PEDESTRIAN            NaN
# 194657            NOT ENOUGH INFORMATION / NOT APPLICABLE            NaN
# 194658       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 194659            NOT ENOUGH INFORMATION / NOT APPLICABLE            NaN
# 194660                   MOTOR VEHICLE OVERTURNED IN ROAD            NaN
# 194661       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 194662       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 194663  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...              Y
# 194664  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194665  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194666  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194667      MOTOR VEHICLE RAN OFF ROAD - HIT FIXED OBJECT            NaN
# 194668  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194669       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END              Y
# 194670  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194671  PEDALCYCLIST STRUCK MOTOR VEHICLE FRONT END AT...            NaN
# 194672       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
#
#        UNDERINFL   WEATHER ROADCOND                LIGHTCOND PEDROWNOTGRNT  \
# 0              N  Overcast      Wet                 Daylight           NaN
# 1              0   Raining      Wet  Dark - Street Lights On           NaN
# 2              0  Overcast      Dry                 Daylight           NaN
# 3              N     Clear      Dry                 Daylight           NaN
# 4              0   Raining      Wet                 Daylight           NaN
# 5              N     Clear      Dry                 Daylight           NaN
# 6              0   Raining      Wet                 Daylight           NaN
# 7              N     Clear      Dry                 Daylight           NaN
# 8              0     Clear      Dry                 Daylight           NaN
# 9              0     Clear      Dry                 Daylight           NaN
# 10             0  Overcast      Dry                 Daylight           NaN
# 11             0     Clear      Dry                 Daylight           NaN
# 12             0   Raining      Wet  Dark - Street Lights On           NaN
# 13             0   Raining      Wet  Dark - No Street Lights           NaN
# 14             N     Clear      Dry  Dark - Street Lights On           NaN
# 15           NaN       NaN      NaN                      NaN           NaN
# 16             0  Overcast      Dry                 Daylight           NaN
# 17             0  Overcast      Dry                 Daylight           NaN
# 18             N     Clear      Dry                 Daylight           NaN
# 19             0   Unknown      Dry                  Unknown           NaN
# 20             N     Clear      Dry  Dark - Street Lights On           NaN
# 21             N     Clear      Dry                 Daylight           NaN
# 22             0     Clear      Dry  Dark - Street Lights On           NaN
# 23             0   Unknown  Unknown                  Unknown           NaN
# 24             N     Clear      Dry                 Daylight           NaN
# 25             N     Clear      Dry                 Daylight           NaN
# 26             N  Overcast      Wet                  Unknown           NaN
# 27             0     Clear      Dry                 Daylight           NaN
# 28             N     Clear      Dry                 Daylight           NaN
# 29             0     Clear      Dry                 Daylight           NaN
# ...          ...       ...      ...                      ...           ...
# 194643         N     Clear      Dry  Dark - Street Lights On           NaN
# 194644         N     Clear      Dry                     Dusk           NaN
# 194645         N     Clear      Dry  Dark - Street Lights On           NaN
# 194646       NaN       NaN      NaN                      NaN           NaN
# 194647         N   Raining      Wet                     Dusk           NaN
# 194648         Y   Raining      Wet  Dark - Street Lights On           NaN
# 194649         N     Clear      Dry  Dark - Street Lights On           NaN
# 194650         N     Clear      Dry                 Daylight           NaN
# 194651         N     Clear      Wet  Dark - Street Lights On           NaN
# 194652         N  Overcast      Wet                     Dusk           NaN
# 194653         Y  Overcast      Wet  Dark - Street Lights On           NaN
# 194654       NaN       NaN      NaN                      NaN           NaN
# 194655       NaN       NaN      NaN                      NaN           NaN
# 194656         N     Clear      Dry                 Daylight           NaN
# 194657         N   Raining      Wet  Dark - Street Lights On           NaN
# 194658         N   Raining      Wet  Dark - Street Lights On           NaN
# 194659         N   Raining      Wet  Dark - Street Lights On           NaN
# 194660         N   Raining      Wet                    Other           NaN
# 194661         Y     Clear      Dry                 Daylight           NaN
# 194662         N     Clear      Dry                     Dusk           NaN
# 194663         N   Raining      Wet                 Daylight           NaN
# 194664         N     Clear      Dry                 Daylight           NaN
# 194665         N     Clear      Dry                 Daylight           NaN
# 194666         N     Clear      Wet                 Daylight           NaN
# 194667         Y   Raining      Wet  Dark - Street Lights On           NaN
# 194668         N     Clear      Dry                 Daylight           NaN
# 194669         N   Raining      Wet                 Daylight           NaN
# 194670         N     Clear      Dry                 Daylight           NaN
# 194671         N     Clear      Dry                     Dusk           NaN
# 194672         N     Clear      Wet                 Daylight           NaN
#
#         SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0              NaN      NaN         10
# 1        6354039.0      NaN         11
# 2        4323031.0      NaN         32
# 3              NaN      NaN         23
# 4        4028032.0      NaN         10
# 5              NaN      NaN         10
# 6        8344002.0      NaN         10
# 7              NaN      NaN          5
# 8        6166014.0      NaN         32
# 9        6079001.0      NaN         10
# 10       6145029.0      NaN         22
# 11       5223041.0      NaN         10
# 12       3137016.0      NaN         14
# 13       5356027.0      NaN         32
# 14             NaN      NaN         30
# 15             NaN      NaN
# 16       5182022.0      NaN         28
# 17       4016025.0      NaN         14
# 18             NaN      NaN         14
# 19       9152035.0      NaN         32
# 20             NaN      NaN         14
# 21             NaN      NaN         10
# 22       8200013.0      NaN         32
# 23       4256026.0      NaN         51
# 24             NaN        Y         14
# 25             NaN      NaN          5
# 26      10317016.0      NaN         28
# 27       7204015.0      NaN         10
# 28             NaN      NaN         23
# 29       6320040.0      NaN         32
# ...            ...      ...        ...
# 194643         NaN      NaN         20
# 194644         NaN      NaN         10
# 194645         NaN      NaN         16
# 194646         NaN      NaN
# 194647         NaN      NaN          0
# 194648         NaN      NaN         10
# 194649         NaN      NaN         28
# 194650         NaN      NaN         32
# 194651         NaN      NaN          0
# 194652         NaN      NaN         32
# 194653         NaN      NaN         32
# 194654         NaN      NaN
# 194655         NaN      NaN
# 194656         NaN      NaN          2
# 194657         NaN      NaN         11
# 194658         NaN      NaN         14
# 194659         NaN      NaN         32
# 194660         NaN      NaN         52
# 194661         NaN      NaN         29
# 194662         NaN      NaN         32
# 194663         NaN      NaN         10
# 194664         NaN      NaN         10
# 194665         NaN      NaN         10
# 194666         NaN      NaN         10
# 194667         NaN      NaN         50
# 194668         NaN      NaN         24
# 194669         NaN      NaN         13
# 194670         NaN      NaN         28
# 194671         NaN      NaN          5
# 194672         NaN      NaN         14
#
#                                                ST_COLDESC  SEGLANEKEY  \
# 0                                       Entering at angle           0
# 1       From same direction - both going straight - bo...           0
# 2                                  One parked--one moving           0
# 3                        From same direction - all others           0
# 4                                       Entering at angle           0
# 5                                       Entering at angle           0
# 6                                       Entering at angle           0
# 7                            Vehicle Strikes Pedalcyclist        6855
# 8                                  One parked--one moving           0
# 9                                       Entering at angle           0
# 10                        One car leaving driveway access           0
# 11                                      Entering at angle           0
# 12      From same direction - both going straight - on...           0
# 13                                 One parked--one moving           0
# 14                   From opposite direction - all others           0
# 15                                                    NaN           0
# 16      From opposite direction - one left turn - one ...           0
# 17      From same direction - both going straight - on...           0
# 18      From same direction - both going straight - on...           0
# 19                                 One parked--one moving           0
# 20      From same direction - both going straight - on...           0
# 21                                      Entering at angle           0
# 22                                 One parked--one moving           0
# 23                                           Other object           0
# 24      From same direction - both going straight - on...           0
# 25                           Vehicle Strikes Pedalcyclist           0
# 26      From opposite direction - one left turn - one ...           0
# 27                                      Entering at angle           0
# 28                       From same direction - all others           0
# 29                                 One parked--one moving           0
# ...                                                   ...         ...
# 194643                    One car leaving parked position           0
# 194644                                  Entering at angle           0
# 194645  From same direction - one right turn - one str...           0
# 194646                                                NaN           0
# 194647             Vehicle going straight hits pedestrian           0
# 194648                                  Entering at angle           0
# 194649  From opposite direction - one left turn - one ...           0
# 194650                             One parked--one moving           0
# 194651             Vehicle going straight hits pedestrian           0
# 194652                             One parked--one moving           0
# 194653                             One parked--one moving           0
# 194654                                                NaN           0
# 194655                                                NaN           0
# 194656               Vehicle turning left hits pedestrian           0
# 194657  From same direction - both going straight - bo...           0
# 194658  From same direction - both going straight - on...           0
# 194659                             One parked--one moving           0
# 194660                                 Vehicle overturned           0
# 194661  From opposite direction - one left turn - one ...           0
# 194662                             One parked--one moving           0
# 194663                                  Entering at angle           0
# 194664                                  Entering at angle           0
# 194665                                  Entering at angle           0
# 194666                                  Entering at angle           0
# 194667                                       Fixed object           0
# 194668    From opposite direction - both moving - head-on           0
# 194669  From same direction - both going straight - bo...           0
# 194670  From opposite direction - one left turn - one ...           0
# 194671                       Vehicle Strikes Pedalcyclist        4308
# 194672  From same direction - both going straight - on...           0
#
#         CROSSWALKKEY HITPARKEDCAR
# 0                  0            N
# 1                  0            N
# 2                  0            N
# 3                  0            N
# 4                  0            N
# 5                  0            N
# 6                  0            N
# 7                  0            N
# 8                  0            N
# 9                  0            N
# 10                 0            N
# 11                 0            N
# 12                 0            N
# 13                 0            N
# 14                 0            N
# 15                 0            N
# 16                 0            N
# 17                 0            N
# 18                 0            N
# 19                 0            N
# 20                 0            N
# 21                 0            N
# 22                 0            N
# 23                 0            N
# 24                 0            N
# 25                 0            N
# 26                 0            N
# 27                 0            N
# 28                 0            N
# 29                 0            N
# ...              ...          ...
# 194643             0            N
# 194644             0            N
# 194645             0            N
# 194646             0            N
# 194647             0            N
# 194648             0            N
# 194649             0            N
# 194650             0            Y
# 194651        522257            N
# 194652             0            Y
# 194653             0            Y
# 194654             0            N
# 194655        650595            N
# 194656        523322            N
# 194657             0            N
# 194658             0            N
# 194659             0            Y
# 194660             0            N
# 194661             0            N
# 194662             0            Y
# 194663             0            N
# 194664             0            N
# 194665             0            N
# 194666             0            N
# 194667             0            N
# 194668             0            N
# 194669             0            N
# 194670             0            N
# 194671             0            N
# 194672             0            N
#
# [194673 rows x 38 columns]>
#
# 	 Data Types: SEVERITYCODE        int64
# X                 float64
# Y                 float64
# OBJECTID            int64
# INCKEY              int64
# COLDETKEY           int64
# REPORTNO           object
# STATUS             object
# ADDRTYPE           object
# INTKEY            float64
# LOCATION           object
# EXCEPTRSNCODE      object
# EXCEPTRSNDESC      object
# SEVERITYCODE.1      int64
# SEVERITYDESC       object
# COLLISIONTYPE      object
# PERSONCOUNT         int64
# PEDCOUNT            int64
# PEDCYLCOUNT         int64
# VEHCOUNT            int64
# INCDATE            object
# INCDTTM            object
# JUNCTIONTYPE       object
# SDOT_COLCODE        int64
# SDOT_COLDESC       object
# INATTENTIONIND     object
# UNDERINFL          object
# WEATHER            object
# ROADCOND           object
# LIGHTCOND          object
# PEDROWNOTGRNT      object
# SDOTCOLNUM        float64
# SPEEDING           object
# ST_COLCODE         object
# ST_COLDESC         object
# SEGLANEKEY          int64
# CROSSWALKKEY        int64
# HITPARKEDCAR       object
# dtype: object

# %%
# View the first 3 rows of the data frame
df[:3]
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
#
#     STATUS      ADDRTYPE   INTKEY  \
# 0  Matched  Intersection  37475.0
# 1  Matched         Block      NaN
# 2  Matched         Block      NaN
#
#                                       LOCATION EXCEPTRSNCODE EXCEPTRSNDESC  \
# 0                   5TH AVE NE AND NE 103RD ST                         NaN
# 1   AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N           NaN           NaN
# 2  4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST           NaN           NaN
#
#    SEVERITYCODE.1                    SEVERITYDESC COLLISIONTYPE  PERSONCOUNT  \
# 0               2                Injury Collision        Angles            2
# 1               1  Property Damage Only Collision     Sideswipe            2
# 2               1  Property Damage Only Collision    Parked Car            4
#
#    PEDCOUNT  PEDCYLCOUNT  VEHCOUNT                 INCDATE  \
# 0         0            0         2  2013/03/27 00:00:00+00
# 1         0            0         2  2006/12/20 00:00:00+00
# 2         0            0         3  2004/11/18 00:00:00+00
#
#                   INCDTTM                             JUNCTIONTYPE  \
# 0    3/27/2013 2:54:00 PM   At Intersection (intersection related)
# 1   12/20/2006 6:55:00 PM  Mid-Block (not related to intersection)
# 2  11/18/2004 10:20:00 AM  Mid-Block (not related to intersection)
#
#    SDOT_COLCODE                                       SDOT_COLDESC  \
# 0            11  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...
# 1            16  MOTOR VEHICLE STRUCK MOTOR VEHICLE, LEFT SIDE ...
# 2            14       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END
#
#   INATTENTIONIND UNDERINFL   WEATHER ROADCOND                LIGHTCOND  \
# 0            NaN         N  Overcast      Wet                 Daylight
# 1            NaN         0   Raining      Wet  Dark - Street Lights On
# 2            NaN         0  Overcast      Dry                 Daylight
#
#   PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0           NaN         NaN      NaN         10
# 1           NaN   6354039.0      NaN         11
# 2           NaN   4323031.0      NaN         32
#
#                                           ST_COLDESC  SEGLANEKEY  \
# 0                                  Entering at angle           0
# 1  From same direction - both going straight - bo...           0
# 2                             One parked--one moving           0
#
#    CROSSWALKKEY HITPARKEDCAR
# 0             0            N
# 1             0            N
# 2             0            N

# %% [markdown]
# Identify columns really needed for analysis.
#
# ## Methodology <a name="methodology"></a>

# %%
#Reduce the data frame to the intended columns for use in analysis
col = ['SEVERITYCODE', 'INCDTTM','PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT',
        'WEATHER', 'ROADCOND', 'LIGHTCOND']
accidents = df[col]
accidents[:5]
# Out:
#    SEVERITYCODE                 INCDTTM  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  \
# 0             2    3/27/2013 2:54:00 PM            2         0            0
# 1             1   12/20/2006 6:55:00 PM            2         0            0
# 2             1  11/18/2004 10:20:00 AM            4         0            0
# 3             1    3/29/2013 9:26:00 AM            3         0            0
# 4             2    1/28/2004 8:04:00 AM            2         0            0
#
#    VEHCOUNT   WEATHER ROADCOND                LIGHTCOND
# 0         2  Overcast      Wet                 Daylight
# 1         2   Raining      Wet  Dark - Street Lights On
# 2         3  Overcast      Dry                 Daylight
# 3         3     Clear      Dry                 Daylight
# 4         2   Raining      Wet                 Daylight

# %% [markdown]
# Remove any **null** or **NaN** values from our data, so that the ML algorithms behave correctly.

# %%
# Check for invalid values, such as Null or NaNs. 
accidents[col].isnull().sum()
# Out:
# SEVERITYCODE       0
# INCDTTM            0
# PERSONCOUNT        0
# PEDCOUNT           0
# PEDCYLCOUNT        0
# VEHCOUNT           0
# WEATHER         5081
# ROADCOND        5012
# LIGHTCOND       5170
# dtype: int64

# %%
# Drop the rows that have null or NaN values. Then, reset the indexes
accidents = accidents.dropna()
accidents = accidents.reset_index()
accidents
# Out:
#          index  SEVERITYCODE                 INCDTTM  PERSONCOUNT  PEDCOUNT  \
# 0            0             2    3/27/2013 2:54:00 PM            2         0
# 1            1             1   12/20/2006 6:55:00 PM            2         0
# 2            2             1  11/18/2004 10:20:00 AM            4         0
# 3            3             1    3/29/2013 9:26:00 AM            3         0
# 4            4             2    1/28/2004 8:04:00 AM            2         0
# ...        ...           ...                     ...          ...       ...
# 189332  194668             2   11/12/2018 8:12:00 AM            3         0
# 189333  194669             1   12/18/2018 9:14:00 AM            2         0
# 189334  194670             2    1/19/2019 9:25:00 AM            3         0
# 189335  194671             2    1/15/2019 4:48:00 PM            2         0
# 189336  194672             1   11/30/2018 3:45:00 PM            2         0
#
#         PEDCYLCOUNT  VEHCOUNT   WEATHER ROADCOND                LIGHTCOND
# 0                 0         2  Overcast      Wet                 Daylight
# 1                 0         2   Raining      Wet  Dark - Street Lights On
# 2                 0         3  Overcast      Dry                 Daylight
# 3                 0         3     Clear      Dry                 Daylight
# 4                 0         2   Raining      Wet                 Daylight
# ...             ...       ...       ...      ...                      ...
# 189332            0         2     Clear      Dry                 Daylight
# 189333            0         2   Raining      Wet                 Daylight
# 189334            0         2     Clear      Dry                 Daylight
# 189335            1         1     Clear      Dry                     Dusk
# 189336            0         2     Clear      Wet                 Daylight
#
# [189337 rows x 10 columns]

# %% [markdown]
# After review of the documentation for the data set, the columns of interest here for possible predictive value for **SEVERITYCODE** are the following:
# * WEATHER
# * ROADCOND
# * LIGHTCOND

# %%
def create_barh_plot(df, title, save, color):
    plt.figure(figsize=(15,7))
    ax = df.plot(kind='barh', color = color )
    plt.xlabel('Counts')
    plt.ylabel('Types')
    ax.xaxis.label.set_fontsize(18)
    ax.yaxis.label.set_fontsize(18)
    graph_title = title
    plt.title(graph_title, fontsize = 20, fontweight = 'bold')
    graph_title_for_save = save
    plt.savefig('Car_Accident_Charts/'+ graph_title_for_save + '.png')
    plt.show()

# %%
weather = accidents.WEATHER.value_counts()
print(weather)
create_barh_plot(weather, 'Weather Type Counts', 'weather_counts', 'darkred')
# Out:
# Clear                       111008
# Raining                      33117
# Overcast                     27681
# Unknown                      15039
# Snowing                        901
# Other                          824
# Fog/Smog/Smoke                 569
# Sleet/Hail/Freezing Rain       113
# Blowing Sand/Dirt               55
# Severe Crosswind                25
# Partly Cloudy                    5
# Name: WEATHER, dtype: int64

# %% [markdown]
# The **WEATHER** column has 11 different options for values. We can see that the option for a 'Clear' with 1,11,135 weather patterns is more prevelant, with 'Rain' being at 33,145 next following closely with 'Overcast' with 27,714.

# %%
roadcond = accidents.ROADCOND.value_counts()
print(roadcond)
create_barh_plot(roadcond, 'Road Condition Type Counts', 'roadcond_counts', 'darkblue')
# Out:
# Dry               124510
# Wet                47474
# Unknown            15078
# Ice                 1209
# Snow/Slush          1004
# Other                132
# Standing Water       115
# Sand/Mud/Dirt         75
# Oil                   64
# Name: ROADCOND, dtype: int64

# %% [markdown]
# Now, we see for **ROADCOND** has 9 options for values, with 'Dry' coming in at 124,510 being the most apparent.

# %%
lightcond = accidents.LIGHTCOND.value_counts()
print(lightcond)
create_barh_plot(lightcond, 'Light Condition Type Counts', 'lightcond_counts', 'black')
# Out:
# Daylight                    116137
# Dark - Street Lights On      48507
# Unknown                      13473
# Dusk                          5902
# Dawn                          2502
# Dark - No Street Lights       1537
# Dark - Street Lights Off      1199
# Other                          235
# Dark - Unknown Lighting         11
# Name: LIGHTCOND, dtype: int64

# %% [markdown]
# We can see all of the values in **LIGHTCOND** in each value and 'Daylight' is the most prevelant here with 116,137 records.

# %%
#Change INCDTTM to datetime format for extraction of year and month for new columns. 
accidents['INCDTTM_dt'] = pd.to_datetime(accidents.INCDTTM)
accidents['INCDTTM_year'] = accidents.INCDTTM_dt.dt.year
accidents['INCDTTM_month'] = accidents.INCDTTM_dt.dt.month
accidents['INCDTTM_year_str'] = accidents.INCDTTM_year.astype(str)
accidents['INCDTTM_month_str'] = accidents.INCDTTM_month.astype(str)
accidents['INCDTTM_year_month'] = accidents[['INCDTTM_year_str','INCDTTM_month_str']].apply(lambda x: '-'.join(x),axis=1)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Convert all column's object values to integers. 
weather_dict = {'Overcast':1, 'Raining':2, 'Clear':3, 'Other':4, 'Snowing':5,
               'Fog/Smog/Smoke':6, 'Sleet/Hail/Freezing Rain':7, 'Blowing Sand/Dirt':8,
               'Severe Crosswind':9, 'Partly Cloudy':10}
accidents['WEATHER_int'] = accidents.WEATHER.apply(lambda x: weather_dict.get(x)).fillna(0).astype(int)

roadcond_dict = {'Wet':1, 'Dry':2, 'Unknown':3, 'Snow/Slush':4, 'Ice':5, 'Other':6,
                'Sand/Mud/Dirt':7, 'Standing Water':8, 'Oil':9}
accidents['ROADCOND_int'] = accidents.ROADCOND.apply(lambda x: roadcond_dict.get(x)).fillna(0).astype(int)

light_dict = {'Daylight':1, 'Dark - Street Lights On':2, 'Dark - No Street Lights':3,
             'Unknown':4, 'Dusk':5, 'Dawn':6, 'Dark - Street Lights Off':7,
             'Other':8, 'Dark - Unknown Lighting':9}
accidents['LIGHTCOND_int'] = accidents.LIGHTCOND.apply(lambda x: light_dict.get(x)).fillna(0).astype(int)

#Assign seasons to weather in Seattle, as the seasonality may have an impact on the predictability of accident serverity. 
seattle_seasons = {12:'Winter', 1:'Winter', 2:'Winter',3:'Spring',4:'Spring',5:'Spring', 6:'Summer',7:'Summer', 8:'Summer',9:'Fall',10:'Fall',11:'Fall'}
accidents['SEATTLE_SEASONS'] = accidents.INCDTTM_month .apply(lambda x: seattle_seasons.get(x))

#View the first 5 rows
accidents[:5]
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    SEVERITYCODE                 INCDTTM  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  \
# 0             2    3/27/2013 2:54:00 PM            2         0            0
# 1             1   12/20/2006 6:55:00 PM            2         0            0
# 2             1  11/18/2004 10:20:00 AM            4         0            0
# 3             1    3/29/2013 9:26:00 AM            3         0            0
# 4             2    1/28/2004 8:04:00 AM            2         0            0
#
#    VEHCOUNT   WEATHER ROADCOND                LIGHTCOND          INCDTTM_dt  \
# 0         2  Overcast      Wet                 Daylight 2013-03-27 14:54:00
# 1         2   Raining      Wet  Dark - Street Lights On 2006-12-20 18:55:00
# 2         3  Overcast      Dry                 Daylight 2004-11-18 10:20:00
# 3         3     Clear      Dry                 Daylight 2013-03-29 09:26:00
# 4         2   Raining      Wet                 Daylight 2004-01-28 08:04:00
#
#    INCDTTM_year  INCDTTM_month INCDTTM_year_str INCDTTM_month_str  \
# 0          2013              3             2013                 3
# 1          2006             12             2006                12
# 2          2004             11             2004                11
# 3          2013              3             2013                 3
# 4          2004              1             2004                 1
#
#   INCDTTM_year_month  WEATHER_int  ROADCOND_int  LIGHTCOND_int SEATTLE_SEASONS
# 0             2013-3            1             1              1          Spring
# 1            2006-12            2             1              2          Winter
# 2            2004-11            1             2              1            Fall
# 3             2013-3            3             2              1          Spring
# 4             2004-1            2             1              1          Winter

# %% [markdown]
# Crete new dataframe with the columns we *think* need for ML predictions.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %%
#Create new dataframe to create a correlation heatmap of the different variables for prediction.
int_cols = ['SEVERITYCODE','INCDTTM_dt', 'INCDTTM_year', 'INCDTTM_month', 'INCDTTM_year_str',
       'INCDTTM_month_str', 'INCDTTM_year_month','WEATHER_int', 'ROADCOND_int', 'LIGHTCOND_int', 'SEATTLE_SEASONS']
severity = accidents[int_cols]
severity[:5]
# Out:
#    SEVERITYCODE          INCDTTM_dt  INCDTTM_year  INCDTTM_month  \
# 0             2 2013-03-27 14:54:00          2013              3
# 1             1 2006-12-20 18:55:00          2006             12
# 2             1 2004-11-18 10:20:00          2004             11
# 3             1 2013-03-29 09:26:00          2013              3
# 4             2 2004-01-28 08:04:00          2004              1
#
#   INCDTTM_year_str INCDTTM_month_str INCDTTM_year_month  WEATHER_int  \
# 0             2013                 3             2013-3            1
# 1             2006                12            2006-12            2
# 2             2004                11            2004-11            1
# 3             2013                 3             2013-3            3
# 4             2004                 1             2004-1            2
#
#    ROADCOND_int  LIGHTCOND_int SEATTLE_SEASONS
# 0             1              1          Spring
# 1             1              2          Winter
# 2             2              1            Fall
# 3             2              1          Spring
# 4             1              1          Winter

# %% [markdown]
# Based on one of the above hypotheses, lets take a look at the SEATTLE_SEASONS column. Lets see how many accidents occurred each year per season.

# %%
seasons  = severity.groupby(['SEATTLE_SEASONS'])['INCDTTM_year'].sum()
seasons
# Out:
# SEATTLE_SEASONS
# Fall      100982730
# Spring     98326040
# Summer     98993913
# Winter     93213486
# Name: INCDTTM_year, dtype: int64

# %%
#Plot these values in a histogram
plt.figure(figsize=(15,5))
colors = ['red', 'green', 'blue', 'grey']
# seasons_df.hist(density = True, histtype = 'bar')
severity.groupby(['SEATTLE_SEASONS'])['INCDTTM_year'].hist(density = True, histtype = 'bar', ec='black')
plt.grid(False)
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Frequency by Season', fontsize = 14)
plt.title('Frequency of Accidents for Each Seattle Season from 2004-2020', fontsize = 18)
plt.legend(['Fall', 'Winter', 'Spring', 'Summer'], title = 'Seattle Seasons')
graph_title_save = 'season_hist'
plt.savefig('Car_Accident_Charts/' + graph_title_save + '.png')
plt.show()

# %% [markdown]
# Doesn't appear to be any differences across seasons for the provided data.

# %%
# Create a heatmap based on the Pearson R correlations to each int variable
severity_corr = severity[['WEATHER_int', 'ROADCOND_int', 'LIGHTCOND_int']].corr()
ax = sns.heatmap(severity_corr, cmap='coolwarm', annot=True, fmt='.1f')
ax.figure.set_size_inches(15,5)
plt.xlabel('Features')
plt.ylabel('Features')
ax.xaxis.label.set_fontsize(14)
ax.yaxis.label.set_fontsize(14)
graph_title = 'Pearson R Correlation for Possible Features'
plt.title(graph_title, fontsize = 17)
graph_title_save = 'corr_heatmap'
plt.savefig('Car_Accident_Charts/' + graph_title_save + '.png')
plt.show()

# %% [markdown]
# It looks like we have our attributes to use for our ML algorithms. HINT: **WEATHER**, **ROADCOND**, and **LIGHTCOND**.

# %% [markdown]
# ## Prediction <a name="prediction"></a>
#
# #### Data Preprocessing
# In order to use the scikit-learn library, we need to convert the items from Pandas into a Numpy array.
# * X as the feature vector ('WEATHER', 'ROADCOND', 'LIGHCOND')
# * y as the predicted variable ('SEVERITYCODE')
#
# The ML algorithms chosen were Decision Tree, K Nearest Neighbor (KNN), and Logistic Regression.

# %%
X = accidents[['WEATHER_int', 'ROADCOND_int', 'LIGHTCOND_int']].values
X[0:5]
# Out:
# array([[1, 1, 1],
#        [2, 1, 2],
#        [1, 2, 1],
#        [3, 2, 1],
#        [2, 1, 1]])

# %%
y = accidents[['SEVERITYCODE']].values
y[0:5]
# Out:
# array([[2],
#        [1],
#        [1],
#        [1],
#        [2]])

# %% [markdown]
# Split these features into train_test_split, using 80% train and 20% test.

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report, jaccard_similarity_score, f1_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
shift_ml = 'ML for Shift \n'
shift_ml += '\t X_train: ' + str(X_train.shape[0]) + '\n'
shift_ml += '\t y_train: ' + str(y_train.shape[0]) + '\n'
shift_ml += '\t X_test: ' + str(X_test.shape[0]) + '\n'
shift_ml += '\t y_test: ' + str(y_test.shape[0]) + '\n'
print(shift_ml)
# Out:
# ML for Shift
# 	 X_train: 155738
# 	 y_train: 155738
# 	 X_test: 38935
# 	 y_test: 38935

# %%
def heatmap_for_confusion(df):
    fix,ax = plt.subplots(figsize = (15, 7))
    sns.heatmap(df, annot = True, fmt = 'd', cmap= 'Reds')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    graph_title = 'Heatmap for Confusion Matrix for Machine Learning Algorithms' 
    plt.show()

# %% [markdown]
# **Decision Tree Classifier**
#
# According to the website *TowardsDataScience.com* "a Decision Tree is a simple representation for classifying examples. It is a Supervised Machine Learning where the data is continuously split according to a certain parameter.
# Decision Tree consists of :
#
#     Nodes : Test for the value of a certain attribute.
#     Edges/ Branch : Correspond to the outcome of a test and connect to the next node or leaf.
#     Leaf nodes : Terminal nodes that predict the outcome (represent class labels or class distribution)."
#
# TowardsDataScience.com (2020) *Decision Tree Classification*. https://towardsdatascience.com/decision-tree-classification-de64fc4d5aac

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
print(model)

model.fit(X_train, y_train)
y_pred_DecisionTree = model.predict(X_test)

conf_mat_DecisionTree = confusion_matrix(y_test, y_pred_DecisionTree)
print(conf_mat_DecisionTree)

class_report = classification_report(y_test, y_pred_DecisionTree)
print(class_report)
heatmap_for_confusion(conf_mat_DecisionTree)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# [[27295    17]
#  [11611    12]]
#               precision    recall  f1-score   support
#
#            1       0.70      1.00      0.82     27312
#            2       0.41      0.00      0.00     11623
#
#    micro avg       0.70      0.70      0.70     38935
#    macro avg       0.56      0.50      0.41     38935
# weighted avg       0.62      0.70      0.58     38935

# %% [markdown]
# **K Nearest Neighbor (KNN)**
#
# The KNN model is a supervised ml, where the data are 'trained' with points that corresond to their classification. Once a point is predicted, the model takes the nearest 'Kth' points to determine classification.

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN

model = KNN(n_neighbors = 3)
print(model)

model.fit(X_train, y_train)
y_pred_knn = model.predict(X_test)
print(y_pred_knn[:5])

conf_mat = confusion_matrix(y_test, y_pred_knn)

class_report = classification_report(y_test, y_pred_knn)
print(class_report)
heatmap_for_confusion(conf_mat)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# [2 2 1 2 1]
#               precision    recall  f1-score   support
#
#            1       0.71      0.80      0.75     27312
#            2       0.34      0.24      0.28     11623
#
#    micro avg       0.63      0.63      0.63     38935
#    macro avg       0.53      0.52      0.52     38935
# weighted avg       0.60      0.63      0.61     38935

# %% [markdown]
# **Logistic Regression**
#
# According to *GeeksforGeeks.com*, "a Logistic regression is basically a supervised classification algorithm. In a classification problem, the target variable(or output), y, can take only discrete values for given set of features(or inputs), X. Contrary to popular belief, logistic regression IS a regression model. The model builds a regression model to predict the probability that a given data entry belongs to the category numbered as “1”. Just like Linear regression assumes that the data follows a linear function, Logistic regression models the data using the sigmoid function."
#
# Geeksforgeeks.org (2020) *Understanding Logistic Regression*. https://www.geeksforgeeks.org/understanding-logistic-regression/

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
print(model)
model.fit(X_train, y_train)
y_pred_logReg = model.predict(X_test)
# print(y_pred_logReg)

conf_mat_logReg = confusion_matrix(y_test, y_pred_logReg)
class_report = classification_report(y_test, y_pred_logReg)
print(class_report)

heatmap_for_confusion(conf_mat_logReg)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#               precision    recall  f1-score   support
#
#            1       0.70      1.00      0.82     27312
#            2       0.30      0.00      0.01     11623
#
#    micro avg       0.70      0.70      0.70     38935
#    macro avg       0.50      0.50      0.41     38935
# weighted avg       0.58      0.70      0.58     38935

# %% [markdown]
# ## Results and Evaluation <a name="results"></a>

# %% [markdown]
# The definitions are listed here:
#
# According to machinelearningmastery.com(2020) and statisticshowto.com(2020):
#
# * **Precision** quantifies the number of positive class predictions that actually belong to the positive class.
# * **Recall** quantifies the number of positive class predictions made out of all positive examples in the dataset.
# * **F-Measure** provides a single score that balances both the concerns of precision and recall in one number.
# * **Jaccard Index** compares members for two sets to see which members are shared and which are distinct. It’s a measure of similarity for the two sets of data, with a range from 0% to 100%. The higher the percentage, the more similar the two populations.

# %%
#This block of code will provide the Jaccard and F1 Scores for each algorithm's performance
ml_output_scores = 'Jaccard and F1 Scores \n'
ml_output_scores += '\t Decision Trees Scores: ' + '\n'
ml_output_scores += '\t\t f1 score: ' +  str(f1_score(y_test, y_pred_DecisionTree, average='weighted'))+ '\n'
ml_output_scores += '\t\t jaccard score: ' +  str(jaccard_similarity_score(y_test, y_pred_DecisionTree))+ '\n'
ml_output_scores += '\n'
ml_output_scores += '\t KNN Scores: ' + '\n'
ml_output_scores += '\t\t f1 score: ' +  str(f1_score(y_test, y_pred_knn, average='weighted')) + '\n'
ml_output_scores += '\t\t jaccard score: ' +  str(jaccard_similarity_score(y_test, y_pred_knn)) +'\n'
ml_output_scores += '\n'
ml_output_scores += '\t Logistic Regression Scores: ' + '\n'
ml_output_scores += '\t\t f1 score: ' +  str(f1_score(y_test, y_pred_logReg, average='weighted')) + '\n'
ml_output_scores += '\t\t jaccard score: ' +  str(jaccard_similarity_score(y_test, y_pred_logReg))+ '\n'
ml_output_scores += '\n'
print(ml_output_scores)
# Out:
# Jaccard and F1 Scores
# 	 Decision Trees Scores:
# 		 f1 score: 0.5789111057668044
# 		 jaccard score: 0.7013484011814562
#
# 	 KNN Scores:
# 		 f1 score: 0.6128976892576841
# 		 jaccard score: 0.63418518042892
#
# 	 Logistic Regression Scores:
# 		 f1 score: 0.5794019346198768
# 		 jaccard score: 0.7004237832284577

# %%
#Lets see how the models performed
from sklearn.model_selection import cross_validate, cross_val_score

models = [
          KNN(),
          LogisticRegression(),
          DecisionTreeClassifier()
]
CV=5
cv_df = pd.DataFrame(index = range(CV*len(models)))
entries = []
for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(model, X, y, scoring = 'accuracy', cv = CV)
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))
    cv_df = pd.DataFrame(entries, columns = ['model_name', 'fold_idx', 'accuracy'])
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#Now, lets gather the average accuracy across Decision Tree, KNN, and Logistic Regression
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# DecisionTreeClassifier    0.700816
# KNeighborsClassifier      0.636236
# LogisticRegression        0.700097
# Name: accuracy, dtype: float64

# %%
#Box-Whisker Plot of the outputs of the models used above.
f, ax = plt.subplots(figsize = (15,5))
ax = sns.boxplot(x = 'model_name', y = 'accuracy', data = cv_df, palette='viridis')
ax = sns.stripplot(x = 'model_name', y= 'accuracy', data= cv_df, size = 8, jitter = True, color = 'grey',
                   edgecolor = 'black', linewidth = 2)
plt.title ('Box and Whisker Plot of Machine Learning Performance', fontsize = 20, fontweight = 'bold')
ax.set_xlabel('Machine Learning Technique', fontsize = 14)
ax.set_ylabel('Accuracy', fontsize = 14)
graph_title_for_save = ('box_whisker_plot_ML_perf_')
plt.savefig('Car_Accident_Charts/'+ graph_title_for_save + '.png', dpi = 400, bbox_inches = None)
plt.show()

# %% [markdown]
# ## Discussion <a name="discussion"></a>

# %% [markdown]
# In the results above, we used Decision Tree, KNN, and Logisitic Regression to attempt to solve our question for the local government officials of Seattle, Washington. In chosing a Kth value of 3 really improved the accuracy, up to 68.5% accuracy in predicting the severity level. However, Decision Tree accuracy was at 69.8% compared to Logistic Regression, which was at 69.7% accuracy of predicting traffic severity levels in Seattle.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# By using the sample historical collision data, I chose to use the environmental conditions (i.e., weather, road, and light conditions) that were associated with severity level of accidents in Seattle. I created a machine learning model based on classification algorithms to predict traffic accident severity in Seattle. I would recommend using a Decision Tree or Logistic Regression for prediction of severity levels.
